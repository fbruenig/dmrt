# %%
import sys
sys.path.append('../../dmrt/')
sys.path.append('../../lange/')

# %%
import diffTools
import numpy as np
import matplotlib.pyplot as plt
import pylange

# %%
# Do doublewell simulation and analyse
radii=np.linspace(-1,1,num=100)

inp = pylange.lange(P=6,N=0.1,m=0.01,G=1, dt=0.01)
dists,pxtp,cts = difft.compute(inp[:,:2], radii=radii, mode='tftpbins',verb=True)
plt.plot(dists,pxtp,label="overdamped")
inp = pylange.lange(P=6,N=0.1,m=10,G=1, dt=0.01)
dists,pxtp,cts = difft.compute(inp[:,:2], radii=radii, mode='tftpbins',verb=True)
plt.plot(dists,pxtp,label="inertial")
plt.legend()
plt.show()
# Out:
# ../../dmrt/diffTools.py:50: RuntimeWarning: invalid value encountered in true_divide
#   pxtp = pxtp/total
# ../../dmrt/diffTools.py:50: RuntimeWarning: invalid value encountered in true_divide
#   pxtp = pxtp/total
